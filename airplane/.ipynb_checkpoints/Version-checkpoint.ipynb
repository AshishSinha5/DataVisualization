# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#                                   Severity  Safety_Score  \
# 0                Minor_Damage_And_Injuries     49.223744
# 1                Minor_Damage_And_Injuries     62.465753
# 2        Significant_Damage_And_Fatalities     63.059361
# 3  Significant_Damage_And_Serious_Injuries     48.082192
# 4        Significant_Damage_And_Fatalities     26.484018
#
#    Days_Since_Inspection  Total_Safety_Complaints  Control_Metric  \
# 0                     14                       22       71.285324
# 1                     10                       27       72.288058
# 2                     13                       16       66.362808
# 3                     11                        9       74.703737
# 4                     13                       25       47.948952
#
#    Turbulence_In_gforces  Cabin_Temperature  Accident_Type_Code  \
# 0               0.272118              78.04                   2
# 1               0.423939              84.54                   2
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
y = lb.fit_transform(df.iloc[:,0].values)
np.bincount(y)
feat_labels = df.columns[1:]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest = RandomForestClassifier(n_estimators=500,random_state=1)

# %%
X = df.iloc[:,1:].values
forest.fit(X,y)
from sklearn.feature_selection import SelectFromModel

# %%
sfm = SelectFromModel(forest, threshold=0.08, prefit=True)
X_selected = sfm.transform(X)
importances = forest.feature_importances_
indices = np.argsort(importances)[::-1]
for f in range(X_selected.shape[1]):
    print("%2d) %-*s %f"%(f+1, 30, feat_labels[indices[f]], importances[indices[f]]))
# Out:
#  1) Safety_Score                   0.271069
#  2) Days_Since_Inspection          0.175798
#  3) Control_Metric                 0.145960
#  4) Adverse_Weather_Metric         0.100355
#  5) Accident_Type_Code             0.088541

# %%
plt.scatter(df['Days_Since_Inspection'],df['Safety_Score'])

# %%
import seaborn as sns

# %%
sns.scatterplot(df['Safety_Score'], df['Control_Metric'], hue = y, palette=sns.color_palette("hls", 4))

# %%
# %pylab inline
import seaborn
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#                                   Severity  Safety_Score  \
# 0                Minor_Damage_And_Injuries     49.223744
# 1                Minor_Damage_And_Injuries     62.465753
# 2        Significant_Damage_And_Fatalities     63.059361
# 3  Significant_Damage_And_Serious_Injuries     48.082192
# 4        Significant_Damage_And_Fatalities     26.484018
#
#    Days_Since_Inspection  Total_Safety_Complaints  Control_Metric  \
# 0                     14                       22       71.285324
# 1                     10                       27       72.288058
# 2                     13                       16       66.362808
# 3                     11                        9       74.703737
# 4                     13                       25       47.948952
#
#    Turbulence_In_gforces  Cabin_Temperature  Accident_Type_Code  \
# 0               0.272118              78.04                   2
# 1               0.423939              84.54                   2
# ...

# %%
hist(df['Safety_Score'], bins = 20, alpha = 0.8, width = 2.2, range = (-0.5,100.5))
title("Safety Score Frequency")
xlabel("Score")
ylabel("Frequency")
;
# Out:
# ''

# %%
hist(df['Days_Since_Inspection'], alpha = 0.8, width = 0.7, bins =25 ,range = (0,24))
title("Days Since Inspection Frequency")
xticks([i for i in range(24)])
xlabel("Days")
ylabel("Frequency")
;
# Out:
# ''

# %%
hist(df[df['Severity'] == 'Minor_Damage_And_Injuries']['Safety_Score'], bins = 20, alpha = 0.8, width = 2.2, range = (-0.5,100.5))
# Out:
# (array([  1.,   2.,   0.,  23.,  59., 112., 196., 247., 397., 439., 339.,
#         296., 186., 105.,  76.,  48.,   1.,   0.,   0.,   0.]),
#  array([ -0.5 ,   4.55,   9.6 ,  14.65,  19.7 ,  24.75,  29.8 ,  34.85,
#          39.9 ,  44.95,  50.  ,  55.05,  60.1 ,  65.15,  70.2 ,  75.25,
#          80.3 ,  85.35,  90.4 ,  95.45, 100.5 ]),
#  <a list of 20 Patch objects>)

# %%
hist(df[df['Severity'] == 'Significant_Damage_And_Serious_Injuries']['Safety_Score'], bins = 20, alpha = 0.8, width = 2.2, range = (-0.5,100.5))
# Out:
# (array([  1.,   3.,  11.,  83., 128., 201., 372., 425., 416., 367., 270.,
#         179., 114.,  64.,  19.,  46.,  13.,   7.,   5.,   5.]),
#  array([ -0.5 ,   4.55,   9.6 ,  14.65,  19.7 ,  24.75,  29.8 ,  34.85,
#          39.9 ,  44.95,  50.  ,  55.05,  60.1 ,  65.15,  70.2 ,  75.25,
#          80.3 ,  85.35,  90.4 ,  95.45, 100.5 ]),
#  <a list of 20 Patch objects>)

# %%
df.groupby('Severity').mean()
# Out:
#                                          Safety_Score  Days_Since_Inspection  \
# Severity
# Highly_Fatal_And_Damaging                   33.353611              12.764513
# Minor_Damage_And_Injuries                   47.800305              13.170162
# Significant_Damage_And_Fatalities           47.102113              13.071386
# Significant_Damage_And_Serious_Injuries     42.667443              12.808721
#
#                                          Total_Safety_Complaints  \
# Severity
# Highly_Fatal_And_Damaging                               6.337160
# Minor_Damage_And_Injuries                               6.827859
# Significant_Damage_And_Fatalities                       6.486726
# Significant_Damage_And_Serious_Injuries                 6.622206
#
#                                          Control_Metric  \
# Severity
# Highly_Fatal_And_Damaging                     66.541401
# Minor_Damage_And_Injuries                     64.350232
# ...

# %%
hist(df['new_metric'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-31364c927712> in <module>
# ----> 1 hist(df['new_metric'])
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2640         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2641         color=color, label=label, stacked=stacked, normed=normed,
# -> 2642         **({"data": data} if data is not None else {}), **kwargs)
#    2643
#    2644
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
# ...

# %%
df['new_metric']
# Out:
# 0       28.441558
# 1       16.008772
# 2       20.615496
# 3       22.877493
# 4       49.086207
#           ...
# 9995    14.255492
# 9996    24.773756
# 9997    61.032787
# 9998    14.232331
# 9999    26.000000
# Name: new_metric, Length: 10000, dtype: float64

# %%
df['Days_Since_Inspection'].std()
# Out:
# 3.5398030751132055

# %%
hist(df['new_metric'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-31364c927712> in <module>
# ----> 1 hist(df['new_metric'])
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2640         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2641         color=color, label=label, stacked=stacked, normed=normed,
# -> 2642         **({"data": data} if data is not None else {}), **kwargs)
#    2643
#    2644
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
# ...
